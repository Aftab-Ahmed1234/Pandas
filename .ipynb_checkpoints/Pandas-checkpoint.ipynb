# %% [markdown]
# # DataFrame

# %%
import pandas as pd
data={
    "Name":["Aftab","Ghaffar","Arslan","Abdullah"],
    "Age":[20,18,22,21],
    "Marks":[100,80,85,95]
}
df=pd.DataFrame(data)
print(df)
# Out:
#        Name  Age  Marks
# 0     Aftab   20    100
# 1   Ghaffar   18     80
# 2    Arslan   22     85
# 3  Abdullah   21     95
