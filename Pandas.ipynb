# %% [markdown]
# # DataFrame

# %%
import pandas as pd
data={
    "Name":["Aftab","Ghaffar","Arslan","Abdullah"],
    "Age":[20,18,22,21],
    "Marks":[100,80,85,95]
}
df=pd.DataFrame(data)
print(df)
# Out:
#        Name  Age  Marks
# 0     Aftab   20    100
# 1   Ghaffar   18     80
# 2    Arslan   22     85
# 3  Abdullah   21     95

# %%
#Return row 0
import pandas as pd

data={
    "Name":["Aftab","Ghaffar","Arslan","Abdullah"],
    "Age":[20,18,22,21],
    "Marks":[100,80,85,95]   
}
df=pd.DataFrame(data)
print(df.loc[0])
# Out:
# Name     Aftab
# Age         20
# Marks      100
# Name: 0, dtype: object

# %%
print(df.loc[[0,1]])
# Out:
#       Name  Age  Marks
# 0    Aftab   20    100
# 1  Ghaffar   18     80

# %%
import pandas as pd
data={
    "Name":["Aftab","Ghaffar","Arslan","Abdullah"],
    "Age":[20,18,22,21],
    "Marks":[100,80,85,95]
}
df=pd.DataFrame(data,index=["Student1","Student2","Student3","Student4"])
print(df)
# Out:
#               Name  Age  Marks
# Student1     Aftab   20    100
# Student2   Ghaffar   18     80
# Student3    Arslan   22     85
# Student4  Abdullah   21     95

# %%
print(df.loc["Student1"])
# Out:
# Name     Aftab
# Age         20
# Marks      100
# Name: Student1, dtype: object

# %%
import pandas as pd
df=pd.read_excel("C:\\Users\\N TEACH\\Macine laening\\Pandas\\Aftab.csv.xlsx")
print(df)
# Out:
#        Name  Age  Marks
# 0     Aftab   20    100
# 1   Ghaffar   18     80
# 2    Arslan   22     85
# 3  Abdullah   21     95

# %%
import pandas as pd
df=pd.read_excel(r"C:\Users\N TEACH\Macine laening\Pandas\Aftab.csv.xlsx")
print(df)
# Out:
#        Name  Age  Marks
# 0     Aftab   20    100
# 1   Ghaffar   18     80
# 2    Arslan   22     85
# 3  Abdullah   21     95

# %%
import pandas as pd
df=pd.read_excel("C:/Users/N TEACH/Macine laening/Pandas/Aftab.csv.xlsx")
print(df)
# Out:
#        Name  Age  Marks
# 0     Aftab   20    100
# 1   Ghaffar   18     80
# 2    Arslan   22     85
# 3  Abdullah   21     95

# %% [markdown]
# # Basic Operations of DataFrame

# %%
print("First 2 rows")
print(df.head(2))
print("\nColumns")
print(df.columns)
print("\nStatetics")
print(df.describe())
# Out:
# First 2 rows
#       Name  Age  Marks
# 0    Aftab   20    100
# 1  Ghaffar   18     80
#
# Columns
# Index(['Name', 'Age', 'Marks'], dtype='object')
#
# Statetics
#              Age       Marks
# count   4.000000    4.000000
# mean   20.250000   90.000000
# std     1.707825    9.128709
# min    18.000000   80.000000
# 25%    19.500000   83.750000
# 50%    20.500000   90.000000
# 75%    21.250000   96.250000
# max    22.000000  100.000000

# %% [markdown]
# # Data Cleaning

# %%
# Bad data could be:

# Empty cells
# Data in wrong format
# Wrong data
# Duplicates

# %%
#DataSet with Missing Values
import pandas as pd
import numpy as np
data={
    "Name":["Aftab",None,"Arslan","Abdullah"],
    "Age":[20,18,np.nan,21],
    "Marks":[20,np.nan,85,95]
    
}
df=pd.DataFrame(data)
print(df)
# Out:
#        Name   Age  Marks
# 0     Aftab  20.0   20.0
# 1      None  18.0    NaN
# 2    Arslan   NaN   85.0
# 3  Abdullah  21.0   95.0

# %%
# Checkin Missing Values
print(df.isnull())
# Out:
#     Name    Age  Marks
# 0  False  False  False
# 1   True  False   True
# 2  False   True  False
# 3  False  False  False

# %%
print(df.isnull().sum())
# Out:
# Name     1
# Age      1
# Marks    1
# dtype: int64

# %%
clean_df=df.dropna()
print(clean_df.to_string())
# Out:
#        Name   Age  Marks
# 0     Aftab  20.0   20.0
# 3  Abdullah  21.0   95.0
